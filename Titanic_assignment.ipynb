# %% [markdown]
# <a href="https://colab.research.google.com/github/shikhasaraf51/Data-Visualization-Titanic-Dataset/blob/main/Titanic_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
data = pd.read_csv(url)

# %%
# Disply the first few rows of the dataset
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
### Question 1: What is the distribution of passenger ages on the Titanic?
# Plotting age distribution with density plot
sns.kdeplot(data['Age'], fill='true', color='green')
plt.title('Distribution of Passenger Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Inference-- Most passengers were aged between 20 and 40

# %%
# Plotting age distribution with violin plot
sns.violinplot(x='Age', data=data)
plt.title('Distribution of Passenger Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
### Question 2: How does the survival rate vary based on passenger class (Pclass)
# Plotting survival by passenger class
sns.countplot(x='Pclass', hue='Survived', data=data, palette='pastel')
plt.title('Survival by Passenger Class')
plt.show()

# Calculate survival rate by class
survival_class = data.groupby('Pclass')['Survived'].mean() * 100
print("Survival Rate by Passenger Class:\n", survival_class)
# Out:
# Survival Rate by Passenger Class:
#  Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
###Inference :
# - Passengers in first class have the highest survival rate, whereas those in 3rd class have the lowest
# - Passengers who could not survive are less in class 1, little more in class 2 and highest in class 3.

# %%
### Question 3: Is there a relationship between the fare paid and the likelihood of survival?
# Plotting Fare vs Survival
sns.boxplot(x='Survived', y= 'Fare', data=data, palette='cool')
plt.title('Fare vs Survival')
plt.show()
# Out:
# <ipython-input-8-9629ee3a1965>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Survived', y= 'Fare', data=data, palette='cool')

# %%
### Inference : Passengers who survived tend to have paid higher

# %%
###Question 4: What is the overall survival rate?
# Plotting the survival count
sns.countplot(x='Survived', data=data, palette='viridis')
plt.title('Survival Count (0= Not Survived, 1=Survived)')
plt.show()

# Calculate Survival Rate
survival_rate = data['Survived'].mean() * 100
print(f"Overall Survival Rate: {survival_rate:.2f}%")
# Out:
# <ipython-input-16-14d910e79f59>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=data, palette='viridis')
# Overall Survival Rate: 38.38%

# %%
### Inference:
# Around 38.38% of passengers survived.

# %%
### Question 5: How does gender impact survival rate?
# Plotting survival by gender
sns.countplot(x='Survived', hue='Sex', data=data, palette='viridis')
plt.title('Survival by Gender')
plt.show()

# Calculate survival rate by gender
survival_gender = data.groupby('Sex')['Survived'].mean() * 100
print("Survival Rate by Gender:\n", survival_gender)
# Out:
# Survival Rate by Gender:
#  Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
### Inference:
# - Females had a significantly higher survival rate compared to males.

# %%
### Question 6: How does survival rate vary by age?
# Plotting age vs survival
sns.boxplot(x='Survived', y='Age', data=data, palette='coolwarm')
plt.title('Age vs Survival')
plt.show()
# Out:
# <ipython-input-18-57da72c9a1b2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Survived', y='Age', data=data, palette='coolwarm')

# %%
### Inference:
# Younger passengers had higher survival rates

# %%
### Question 7: How does fare vary among passenger classes?
# Plotting fare distribution by class
sns.boxplot(x='Pclass', y='Fare', data=data, palette='muted')
plt.title('Fare Distribution by Passenger Class')
plt.show()
# Out:
# <ipython-input-19-44d537dfd4ab>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Pclass', y='Fare', data=data, palette='muted')

# %%
### Inference:
# Passengers in 1st class paid significantly higher fares compared to other classes, in 2nd class paid lesser than 1st and the passengers in 3rd class
# paid the lowest fare

# %%
### Question 8: How does embarkation port affect survival?
# Plotting survival by embarkation port
sns.countplot(x='Embarked', hue='Survived', data=data, palette='bright')
plt.title('Survival by Embarkation Port')
plt.show()
# Calculate survival rate by embarkation port
survival_embarked = data.groupby('Embarked')['Survived'].mean() * 100
print("Survival Rate by Embarkation Port:\n", survival_embarked)
# Out:
# Survival Rate by Embarkation Port:
#  Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %%
### Inference:
# Passengers embarking from port 'C' had the highest survival rate.

# %%
### Question 9: Does having siblings/spouses aboard impact survival?
# Plotting survival by siblings/spouses aboard
sns.countplot(x='SibSp', hue='Survived', data=data, palette='Set2')
plt.title('Survival by Siblings/Spouses Aboard')
plt.show()

# %%
### Inference:
# Passengers with 1 siblings/spouses aboard had highest survival rate

# %%
### Question 10: Does having parents/children aboard impact survival?
# Plotting survival by parents/children aboard
sns.countplot(x='Parch', hue='Survived', data=data, palette='Set1')
plt.title('Survival by Parents/Children Aboard')
plt.show()

# %%
### Inference:
# Passengers with 1 and 3 parents/children aboard had higher survival rates

# %%
### Question 11: How does cabin information correlate with survival?
# Extracting cabin presence
sns.countplot(x=data['Cabin'].notnull(), hue=data['Survived'], palette='husl')
plt.title('Survival Based on Cabin Information')
plt.xlabel('Cabin Known (True/False)')
plt.show()

# %%
### Inference:
# Passengers with known cabin information had higher survival rate

# %%
### Question 12: Is there a relationship between ticket class and gender?
# Plotting ticket class by gender
sns.countplot(x='Pclass', hue='Sex', data=data, palette='viridis')
plt.title('Ticket Class Distribution by Gender')
plt.show()

# %%
### Inference:
# More males traveled in 3rd class, while females were more evenly distributed.
